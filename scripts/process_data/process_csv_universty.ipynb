# %%
import pandas as pd

def read_xlsx_from_sheet2(filename):
    # Leer solo la hoja 2 del archivo XLSX
    df = pd.read_excel(filename, sheet_name="Sheet2",header=0)  # Las hojas se indexan desde 0
    
    # Descartar la primera fila y reiniciar el índice
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index(drop=True)

    return df

# Uso de la función
filename = '/home/user/Desktop/MateoCodes/WebScrapingLinkedin/documentacion/RE_EGR_ACR_.xlsx'
data = read_xlsx_from_sheet2(filename)
print(data)
# Out:
# 0      PERIODO_EGRESO PERIODO_GRADO COD_SEDE         SEDE COD_FACULTAD  \
# 0             2009-1S       2009-2S     1101  Sede Bogotá         2053
# 1             2019-1S       2019-2S     1101  Sede Bogotá         2053
# 2             2015-1S       2015-2S     1101  Sede Bogotá         2053
# 3             2019-2S       2020-1S     1101  Sede Bogotá         2050
# 4             2021-2S       2022-1S     1101  Sede Bogotá         2050
# ...               ...           ...      ...          ...          ...
# 101843        2019-1S       2019-2S     1101  Sede Bogotá         2056
# 101844        2012-2S       2013-1S     1101  Sede Bogotá         2053
# 101845        2017-2S       2018-1S     1101  Sede Bogotá         2056
# 101846        2012-2S       2013-1S     1101  Sede Bogotá         2052
# 101847        2013-2S       2014-1S     1101  Sede Bogotá         2049
#
# 0                                                FACULTAD COD_UAB  \
# ...

# %%
# Solo quedarse con los datos necesarios
data = data.loc[:,['PERIODO_EGRESO','PERIODO_GRADO','SEDE','FACULTAD','UAB','PROGRAMA','PLAN','NIVEL','NOMBRES','APELLIDO1','APELLIDO2','CONVOCATORIA','CORREO']]

# %%
# Ahora solo procesar las personas que son de la facultad de ingenieria

data = data[data['FACULTAD'] == 'FACULTAD DE INGENIERÍA']

# %%
data.to_excel('/home/user/Desktop/MateoCodes/WebScrapingLinkedin/documentacion/datos_egresados.xlsx', index=False)
